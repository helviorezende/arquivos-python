# %% [markdown]
# <a href="https://colab.research.google.com/github/helviorezende/arquivos-python/blob/main/covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfcovid20_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_25abr2022/HIST_PAINEL_COVIDBR_2020_Parte1_25abr2022.csv", sep=';', parse_dates=['data'], encoding='ISO-8859-1')

# %%
dfcovid20_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_25abr2022/HIST_PAINEL_COVIDBR_2020_Parte2_25abr2022.csv", sep=';', parse_dates=['data'], encoding='ISO-8859-1')

# %%
dfcovid21_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_25abr2022/HIST_PAINEL_COVIDBR_2021_Parte1_25abr2022.csv", sep=';', parse_dates=['data'], encoding='ISO-8859-1')

# %%
dfcovid21_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_25abr2022/HIST_PAINEL_COVIDBR_2021_Parte2_25abr2022.csv", sep=';', parse_dates=['data'], encoding='ISO-8859-1')

# %%
dfcovid22_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HIST_PAINEL_COVIDBR_25abr2022/HIST_PAINEL_COVIDBR_2022_Parte1_25abr2022.csv", sep=';', parse_dates=['data'],encoding='ISO-8859-1')

# %%
covid21=pd.concat([dfcovid21_1,dfcovid21_2])

# %%
covid20=pd.concat([dfcovid20_1,dfcovid20_2])

# %%
covid22 = dfcovid22_1

# %%
geral = pd.concat([covid20,covid21,covid22])

# %%
geral
# Out:
#               regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN        NaN     76       NaN             NaN
# 1             Brasil    NaN        NaN     76       NaN             NaN
# 2             Brasil    NaN        NaN     76       NaN             NaN
# 3             Brasil    NaN        NaN     76       NaN             NaN
# 4             Brasil    NaN        NaN     76       NaN             NaN
# ...              ...    ...        ...    ...       ...             ...
# 646182  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646183  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646184  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646185  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646186  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#          nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# ...

# %%
geral.data.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                 4271611
# unique                    791
# top       2021-03-26 00:00:00
# freq                     5620
# first     2020-02-25 00:00:00
# last      2022-04-25 00:00:00
# Name: data, dtype: object

# %%
geral.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
geral.isnull().sum()
# Out:
# regiao                          0
# estado                       1094
# municipio                   38411
# coduf                           0
# codmun                      22451
# codRegiaoSaude              38411
# nomeRegiaoSaude             38411
# data                            0
# semanaEpi                       0
# populacaoTCU2019            15960
# casosAcumulado                  0
# casosNovos                      0
# obitosAcumulado                 0
# obitosNovos                     0
# Recuperadosnovos          4270517
# emAcompanhamentoNovos     4270517
# interior/metropolitana      38411
# dtype: int64

# %%
geral['ano'] = geral['data'].dt.year
geral['mes'] = geral['data'].dt.month
geral['dia'] = geral['data'].dt.day

# %%
geral['mes'].replace(1,'janeiro', inplace=True)
geral['mes'].replace(2,'fevereiro', inplace=True)
geral['mes'].replace(3,'marco', inplace=True)
geral['mes'].replace(4,'abril', inplace=True)
geral['mes'].replace(5,'maio', inplace=True)
geral['mes'].replace(6,'junho', inplace=True)
geral['mes'].replace(7,'julho', inplace=True)
geral['mes'].replace(8,'agosto', inplace=True)
geral['mes'].replace(9,'setembro', inplace=True)
geral['mes'].replace(10,'outubro', inplace=True)
geral['mes'].replace(11,'novembro', inplace=True)
geral['mes'].replace(12,'dezembro', inplace=True)

# %%
geral
# Out:
#               regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN        NaN     76       NaN             NaN
# 1             Brasil    NaN        NaN     76       NaN             NaN
# 2             Brasil    NaN        NaN     76       NaN             NaN
# 3             Brasil    NaN        NaN     76       NaN             NaN
# 4             Brasil    NaN        NaN     76       NaN             NaN
# ...              ...    ...        ...    ...       ...             ...
# 646182  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646183  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646184  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646185  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 646186  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#          nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# ...

# %%
geral.isnull().sum()
# Out:
# regiao                          0
# estado                       1094
# municipio                   38411
# coduf                           0
# codmun                      22451
# codRegiaoSaude              38411
# nomeRegiaoSaude             38411
# data                            0
# semanaEpi                       0
# populacaoTCU2019            15960
# casosAcumulado                  0
# casosNovos                      0
# obitosAcumulado                 0
# obitosNovos                     0
# Recuperadosnovos          4270517
# emAcompanhamentoNovos     4270517
# interior/metropolitana      38411
# ano                             0
# mes                             0
# dia                             0
# dtype: int64

# %%
geral.loc[geral.codmun==314810.0, 'municipio']="Patrocinio"
geral.loc[geral.codmun==317020.3, 'municipio']="Abaete"
geral.loc[geral.codmun==317020.0, 'municipio']="Uberlandia"
geral.loc[geral.codmun==310350.4, 'municipio']="Araguari"
geral.loc[geral.codmun==530010.0, 'municipio']="Brasilia"

# %%
#preenchendo missing values
#geral[['estado', 'municipio', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude']] = geral[['estado', 'municipio', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude']].fillna('ausente')
#geral[['Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana']] = geral[['Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana']].fillna(0)

# %%
geral['regiao'].value_counts()
# Out:
# Nordeste        1377399
# Sudeste         1273884
# Sul              909813
# Centro-Oeste     359604
# Norte            349817
# Brasil             1094
# Name: regiao, dtype: int64

# %%
geral['estado'].value_counts()
# Out:
# MG    649831
# SP    491751
# RS    379271
# BA    318471
# PR    304791
# SC    225751
# GO    188511
# PI    171791
# PB    171031
# MA    166471
# PE    142151
# CE    141391
# RN    128471
# PA    110231
# MT    108711
# TO    107191
# AL     79071
# RJ     71471
# MS     60831
# ES     60831
# SE     58551
# AM     47911
# RO     41071
# AC     17511
# AP     12951
# RR     12951
# DF      1551
# Name: estado, dtype: int64

# %%
covid2 = pd.DataFrame()

# %%
crosstab_vg = pd.crosstab(geral['regiao'], geral['obitosAcumulado'])
crosstab_vg.head()
# Out:
# obitosAcumulado  0       1       2       3       4       5       6       \
# regiao
# Brasil               21       1       0       0       1       0       1
# Centro-Oeste      62956   21050   17198   12040   12183    9844   11984
# Nordeste         199154   89581   72264   63236   57191   50484   52495
# Norte             42577   15381   16019   12875   11769   10135    9835
# Sudeste          220657   88900   62960   56342   47041   39726   35798
#
# obitosAcumulado  7       8       9       ...  661938  661960  662026  662151  \
# regiao                                   ...
# Brasil                0       0       0  ...       1       1       1       1
# Centro-Oeste      12467    8930    9953  ...       0       0       0       0
# Nordeste          46014   41544   38255  ...       0       0       0       0
# Norte             10780    9622    7985  ...       0       0       0       0
# Sudeste           34695   32201   27144  ...       0       0       0       0
#
# ...

# %%
municipio = "Uberaba"
situacao = "obitosAcumulado"
uberlandia = geral.loc[geral.municipio==municipio,:]
uberlandia = uberlandia.groupby('data').sum()[situacao].reset_index()

uberlandia = uberlandia.drop('data', axis=1)
uberlandia.columns = [municipio]

covid2 = pd.concat([covid2,uberlandia], ignore_index=False, axis=1)
covid2
# Out:
#      Uberaba
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 755     1531
# 756     1531
# 757     1531
# 758     1531
# 759     1531
#
# [760 rows x 1 columns]

# %%
covid2.plot()

# %%
mg = geral.loc[geral.estado == 'MG',:]

# %%
geral.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana',
#        'ano', 'mes', 'dia'],
#       dtype='object')

# %%
mg
# Out:
#          regiao estado       municipio  coduf    codmun  codRegiaoSaude  \
# 2773    Sudeste     MG             NaN     31       NaN             NaN
# 2774    Sudeste     MG             NaN     31       NaN             NaN
# 2775    Sudeste     MG             NaN     31       NaN             NaN
# 2776    Sudeste     MG             NaN     31       NaN             NaN
# 2777    Sudeste     MG             NaN     31       NaN             NaN
# ...         ...    ...             ...    ...       ...             ...
# 360867  Sudeste     MG  Wenceslau Braz     31  317220.0         31003.0
# 360868  Sudeste     MG  Wenceslau Braz     31  317220.0         31003.0
# 360869  Sudeste     MG  Wenceslau Braz     31  317220.0         31003.0
# 360870  Sudeste     MG  Wenceslau Braz     31  317220.0         31003.0
# 360871  Sudeste     MG  Wenceslau Braz     31  317220.0         31003.0
#
#        nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# ...

# %%
#pd.set_option('display.max_rows', None)
#pd.reset_option('^display.',silent=True )

# %%
#regiaoTotal = geral.drop(['municipio','coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019','casosAcumulado', 'casosNovos','obitosNovos','Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana', 'mes','dia'],axis=1)

# %%
regiaoTotal
# Out:
#               regiao estado  obitosAcumulado   ano
# 0             Brasil    NaN                0  2020
# 1             Brasil    NaN                0  2020
# 2             Brasil    NaN                0  2020
# 3             Brasil    NaN                0  2020
# 4             Brasil    NaN                0  2020
# ...              ...    ...              ...   ...
# 646182  Centro-Oeste     DF            11638  2022
# 646183  Centro-Oeste     DF            11638  2022
# 646184  Centro-Oeste     DF            11638  2022
# 646185  Centro-Oeste     DF            11638  2022
# 646186  Centro-Oeste     DF            11644  2022
#
# [4271611 rows x 4 columns]

# %%
obitoRegiao = regiaoTotal.loc[regiaoTotal.regiao!="Brasil",:]

# %%
obitoRegiao
# Out:
#               regiao estado  obitosAcumulado   ano
# 245            Norte     RO                0  2020
# 246            Norte     RO                0  2020
# 247            Norte     RO                0  2020
# 248            Norte     RO                0  2020
# 249            Norte     RO                0  2020
# ...              ...    ...              ...   ...
# 646182  Centro-Oeste     DF            11638  2022
# 646183  Centro-Oeste     DF            11638  2022
# 646184  Centro-Oeste     DF            11638  2022
# 646185  Centro-Oeste     DF            11638  2022
# 646186  Centro-Oeste     DF            11644  2022
#
# [4270517 rows x 4 columns]

# %%
obitoRegiao.groupby(['ano','regiao','estado','obitosAcumulado']).sum().reset_index()
# Out:
#         ano        regiao estado  obitosAcumulado
# 0      2020  Centro-Oeste     DF                0
# 1      2020  Centro-Oeste     DF                1
# 2      2020  Centro-Oeste     DF                3
# 3      2020  Centro-Oeste     DF                4
# 4      2020  Centro-Oeste     DF                5
# ...     ...           ...    ...              ...
# 70014  2022           Sul     SC            21734
# 70015  2022           Sul     SC            21738
# 70016  2022           Sul     SC            21741
# 70017  2022           Sul     SC            21743
# 70018  2022           Sul     SC            21759
#
# [70019 rows x 4 columns]

# %%
centroOeste = obitoRegiao.loc[obitoRegiao.regiao=="Centro-Oeste",:]

# %%
centroOeste
# Out:
#               regiao estado  obitosAcumulado   ano
# 3879    Centro-Oeste     MS                0  2020
# 3880    Centro-Oeste     MS                0  2020
# 3881    Centro-Oeste     MS                0  2020
# 3882    Centro-Oeste     MS                0  2020
# 3883    Centro-Oeste     MS                0  2020
# ...              ...    ...              ...   ...
# 646182  Centro-Oeste     DF            11638  2022
# 646183  Centro-Oeste     DF            11638  2022
# 646184  Centro-Oeste     DF            11638  2022
# 646185  Centro-Oeste     DF            11638  2022
# 646186  Centro-Oeste     DF            11644  2022
#
# [359604 rows x 4 columns]

# %%
centroOeste['estado'].unique()
# Out:
# array(['MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
obitosMS = centroOeste.loc[centroOeste.estado=="MS",['ano','obitosAcumulado']]

# %%
obitosMS.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosMT = centroOeste.loc[centroOeste.estado=="MT",['ano','obitosAcumulado']]

# %%
obitosMT.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosGO = centroOeste.loc[centroOeste.estado=="GO",['ano','obitosAcumulado']]

# %%
obitosGO.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosDF = centroOeste.loc[centroOeste.estado=="DF",['ano','obitosAcumulado']]

# %%
obitosDF.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
sudeste = geral.loc[geral.regiao=="Sudeste",:]

# %%
sudeste
# Out:
#          regiao estado     municipio  coduf    codmun  codRegiaoSaude  \
# 2773    Sudeste     MG           NaN     31       NaN             NaN
# 2774    Sudeste     MG           NaN     31       NaN             NaN
# 2775    Sudeste     MG           NaN     31       NaN             NaN
# 2776    Sudeste     MG           NaN     31       NaN             NaN
# 2777    Sudeste     MG           NaN     31       NaN             NaN
# ...         ...    ...           ...    ...       ...             ...
# 454937  Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 454938  Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 454939  Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 454940  Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
# 454941  Sudeste     SP  Estiva Gerbi     35  355730.0         35141.0
#
#        nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# ...

# %%
sudeste['estado'].unique()
# Out:
# array(['MG', 'ES', 'RJ', 'SP'], dtype=object)

# %%
centrooeste = geral.loc[geral.regiao=="Centro-Oeste",:]

# %%
centrooeste['estado'].unique()
# Out:
# array(['MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
norte = geral.loc[geral.regiao=="Norte",:]

# %%
norte['estado'].unique()
# Out:
# array(['RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO'], dtype=object)

# %%
nordeste = geral.loc[geral.regiao=="Nordeste",:]

# %%
nordeste['estado'].unique()
# Out:
# array(['MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE', 'BA'], dtype=object)

# %%
sul = geral.loc[geral.regiao=="Sul",:]

# %%
sul['estado'].unique()
# Out:
# array(['PR', 'SC', 'RS'], dtype=object)

# %%
sudeste['municipio'].unique()
# Out:
# array([nan, 'Abadia dos Dourados', 'AbaetÃ©', ..., 'Zacarias',
#        'Chavantes', 'Estiva Gerbi'], dtype=object)

# %%
espiritoSanto = sudeste.loc[sudeste.estado=="ES",:]

# %%
totalObitosES=espiritoSanto.drop(['regiao', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude','nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019','casosAcumulado', 'casosNovos', 'obitosNovos','Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana', 'dia'],axis=1)

# %%
totalObitosES
# Out:
#        estado  obitosAcumulado   ano        mes
# 2931       ES                0  2020  fevereiro
# 2932       ES                0  2020  fevereiro
# 2933       ES                0  2020  fevereiro
# 2934       ES                0  2020  fevereiro
# 2935       ES                0  2020  fevereiro
# ...       ...              ...   ...        ...
# 369952     ES             1409  2022      abril
# 369953     ES             1409  2022      abril
# 369954     ES             1409  2022      abril
# 369955     ES             1409  2022      abril
# 369956     ES             1409  2022      abril
#
# [60831 rows x 4 columns]

# %%
agrupadoES = totalObitosES.groupby(['ano','obitosAcumulado']).sum()

# %%
obitoRegiao['obitosAcumulado'].max()
# Out:
# 168009

# %%
sudeste = obitoRegiao.loc[obitoRegiao.regiao=="Sudeste",:]

# %%
sudeste
# Out:
#          regiao estado  obitosAcumulado   ano
# 2773    Sudeste     MG                0  2020
# 2774    Sudeste     MG                0  2020
# 2775    Sudeste     MG                0  2020
# 2776    Sudeste     MG                0  2020
# 2777    Sudeste     MG                0  2020
# ...         ...    ...              ...   ...
# 454937  Sudeste     SP               36  2022
# 454938  Sudeste     SP               36  2022
# 454939  Sudeste     SP               36  2022
# 454940  Sudeste     SP               36  2022
# 454941  Sudeste     SP               36  2022
#
# [1273884 rows x 4 columns]

# %%
sudeste['obitosAcumulado'].max()
# Out:
# 168009

# %%
sudestemg=sudeste.loc[sudeste.estado=="MG",:]

# %%
sudestemg
# Out:
#          regiao estado  obitosAcumulado   ano
# 2773    Sudeste     MG                0  2020
# 2774    Sudeste     MG                0  2020
# 2775    Sudeste     MG                0  2020
# 2776    Sudeste     MG                0  2020
# 2777    Sudeste     MG                0  2020
# ...         ...    ...              ...   ...
# 360867  Sudeste     MG                7  2022
# 360868  Sudeste     MG                7  2022
# 360869  Sudeste     MG                7  2022
# 360870  Sudeste     MG                7  2022
# 360871  Sudeste     MG                7  2022
#
# [649831 rows x 4 columns]

# %%
sudestemg['obitosAcumulado'].max()
# Out:
# 61227

# %%
sudesterj=sudeste.loc[sudeste.estado=="RJ",:]

# %%
sudesterj['obitosAcumulado'].max()
# Out:
# 73233

# %%
sudestemg.groupby(['ano', 'obitosAcumulado']).sum()
# Out:
#                                                                  regiao  \
# ano  obitosAcumulado
# 2020 0                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      1                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      2                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      3                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      4                SudesteSudesteSudesteSudesteSudesteSudesteSude...
# ...                                                                 ...
# 2022 61204                                                      Sudeste
#      61207                                                      Sudeste
#      61216                                               SudesteSudeste
#      61226                                                      Sudeste
#      61227                                                      Sudeste
#
#                                                                  estado
# ...

# %%
sudestesp=sudeste.loc[sudeste.estado=="SP",['ano','obitosAcumulado']]

# %%
sudestesp['obitosAcumulado'].max()
# Out:
# 168009

# %%
sudestesp
# Out:
#          ano  obitosAcumulado
# 3247    2020                0
# 3248    2020                0
# 3249    2020                0
# 3250    2020                0
# 3251    2020                0
# ...      ...              ...
# 454937  2022               36
# 454938  2022               36
# 454939  2022               36
# 454940  2022               36
# 454941  2022               36
#
# [491751 rows x 2 columns]

# %%
sudestesp.groupby(['ano','obitosAcumulado']).sum().reset_index()
# Out:
#        ano  obitosAcumulado
# 0     2020                0
# 1     2020                1
# 2     2020                2
# 3     2020                3
# 4     2020                4
# ...    ...              ...
# 7379  2022           167986
# 7380  2022           167989
# 7381  2022           168000
# 7382  2022           168007
# 7383  2022           168009
#
# [7384 rows x 2 columns]

# %%
sudesterj.groupby(['ano', 'obitosAcumulado']).sum()
# Out:
#                                                                  regiao  \
# ano  obitosAcumulado
# 2020 0                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      1                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      2                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      3                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      4                SudesteSudesteSudesteSudesteSudesteSudesteSude...
# ...                                                                 ...
# 2022 73146                                                      Sudeste
#      73176                                                      Sudeste
#      73196                                               SudesteSudeste
#      73207                                        SudesteSudesteSudeste
#      73233                                                      Sudeste
#
#                                                                  estado
# ...

# %%
sudestees=sudeste.loc[sudeste.estado=="ES",:]

# %%
sudestees.groupby(['ano','obitosAcumulado']).sum()
# Out:
#                                                                  regiao  \
# ano  obitosAcumulado
# 2020 0                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      1                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      2                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      3                SudesteSudesteSudesteSudesteSudesteSudesteSude...
#      4                SudesteSudesteSudesteSudesteSudesteSudesteSude...
# ...                                                                 ...
# 2022 14376                                                      Sudeste
#      14378                                               SudesteSudeste
#      14384                                                      Sudeste
#      14389                                                      Sudeste
#      14391                   SudesteSudesteSudesteSudesteSudesteSudeste
#
#                                                                  estado
# ...

# %%
geral['regiao'].unique()
# Out:
# array(['Brasil', 'Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'],
#       dtype=object)

# %%
geral['obitosAcumulado'].max()
# Out:
# 662722

# %%
covid = geral.loc[geral.regiao!="Brasil",:]

# %%
centroOeste = obitoRegiao.loc[obitoRegiao.regiao=="Centro-Oeste",:]

# %%
centroOeste['estado'].unique()
# Out:
# array(['MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
norte = obitoRegiao.loc[obitoRegiao.regiao=="Norte",:]

# %%
norte['estado'].unique()
# Out:
# array(['RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO'], dtype=object)

# %%
obitosRO = norte.loc[norte.estado=="RO",['ano','obitosAcumulado']]

# %%
obitosRO.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosAC = norte.loc[norte.estado=="AC",['ano','obitosAcumulado']]

# %%
obitosAC.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosAM = norte.loc[norte.estado=="AM",['ano','obitosAcumulado']]

# %%
obitosAM.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosAP = norte.loc[norte.estado=="AP",['ano','obitosAcumulado']]

# %%
obitosAP.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosPA = norte.loc[norte.estado=="PA",['ano','obitosAcumulado']]

# %%
obitosPA.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosRR = norte.loc[norte.estado=="RR",['ano','obitosAcumulado']]

# %%
obitosRR.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosTO = norte.loc[norte.estado=="TO",['ano','obitosAcumulado']]

# %%
obitosTO.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
nordeste = obitoRegiao.loc[obitoRegiao.regiao=="Nordeste",:]

# %%
nordeste = obitoRegiao.loc[obitoRegiao.regiao=="Nordeste",:]
nordeste['estado'].unique()
# Out:
# array(['MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE', 'BA'], dtype=object)

# %%
obitosMA = nordeste.loc[nordeste.estado=="MA",['ano','obitosAcumulado']]

# %%
obitosMA.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosPI = nordeste.loc[nordeste.estado=="PI",['ano','obitosAcumulado']]

# %%
obitosPI.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosCE = nordeste.loc[nordeste.estado=="CE",['ano','obitosAcumulado']]
obitosCE.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosAL = nordeste.loc[nordeste.estado=="AL",['ano','obitosAcumulado']]
obitosAL.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosBA = nordeste.loc[nordeste.estado=="BA",['ano','obitosAcumulado']]
obitosBA.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosPB = nordeste.loc[nordeste.estado=="PB",['ano','obitosAcumulado']]
obitosPB.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosPE = nordeste.loc[nordeste.estado=="PE",['ano','obitosAcumulado']]
obitosPE.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosRN = nordeste.loc[nordeste.estado=="RN",['ano','obitosAcumulado']]
obitosRN.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosSE = nordeste.loc[nordeste.estado=="SE",['ano','obitosAcumulado']]
obitosSE.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
sul = obitoRegiao.loc[obitoRegiao.regiao=="Sul",:]
sul['estado'].unique()
# Out:
# array(['PR', 'SC', 'RS'], dtype=object)

# %%
obitosPR = sul.loc[sul.estado=="PR",['ano','obitosAcumulado']]
obitosPR.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosSC = sul.loc[sul.estado=="SC",['ano','obitosAcumulado']]
obitosSC.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
obitosRS = sul.loc[sul.estado=="RS",['ano','obitosAcumulado']]
obitosRS.groupby(['ano','obitosAcumulado']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...
